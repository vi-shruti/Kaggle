# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/vi-shruti/Kaggle/blob/master/KaggleSetup.ipynb)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-26dd46ab-c552-4dab-a2b9-d16891049db1" name="files[]" multiple disabled />
#      <output id="result-26dd46ab-c552-4dab-a2b9-d16891049db1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"vshruti","key":"76a4075e52817069bedef382f577a8ca"}'}

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                      title                                               size  lastUpdated          downloadCount
# -------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------
# xvivancos/transactions-from-a-bakery                     Transactions from a bakery                         113KB  2018-09-05 23:42:32           4866
# center-for-policing-equity/data-science-for-good         Data Science for Good: Center for Policing Equity   43MB  2018-10-24 00:27:12           1947
# olistbr/brazilian-ecommerce                              Brazilian E-Commerce Public Dataset by Olist        30MB  2018-10-25 19:46:13           1751
# lava18/google-play-store-apps                            Google Play Store Apps                               2MB  2018-09-18 20:49:49          12950
# ...

# %%
api_token = {"username":"USERNAME","key":"API_KEY"}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c airbus-ship-detection
# Out:
# ...
#   0% 0.00/274k [00:00<?, ?B/s]
# 100% 274k/274k [00:00<00:00, 65.8MB/s]
# ...
#  28% 5.00M/18.0M [00:00<00:00, 42.2MB/s]
# 100% 18.0M/18.0M [00:00<00:00, 111MB/s]
# ...
# 100% 2.12G/2.12G [00:41<00:00, 35.3MB/s]
# 100% 2.12G/2.12G [00:41<00:00, 54.7MB/s]
# ...
# 100% 26.4G/26.4G [18:49<00:00, 45.1MB/s]
# 100% 26.4G/26.4G [18:49<00:00, 25.1MB/s]

# %%
# !mkdir train
# !mkdir test
# Out:
# mkdir: cannot create directory ‘train’: File exists
# mkdir: cannot create directory ‘test’: File exists

# %%
# !unzip -d /train train_v2.zip 
# !unzip -d /test test_v2.zip
# !unzip train_ship_segmentations_v2.csv.zip
# Out:
# Archive:  train_v2.zip
#   inflating: /train/0a74d3ab8.jpg
#   inflating: /train/06f92b952.jpg
#   inflating: /train/f6b822800.jpg
#   inflating: /train/59d14509a.jpg
#   inflating: /train/a4b1eb1ee.jpg
#   inflating: /train/20efacdf0.jpg
#   inflating: /train/5a91ff1ba.jpg
#   inflating: /train/872aa8dca.jpg
#   inflating: /train/24cf12c26.jpg
#   inflating: /train/2320d17dc.jpg
#   inflating: /train/e6f7a5076.jpg
#   inflating: /train/9702e3e9b.jpg
#   inflating: /train/e449fe1d0.jpg
#   inflating: /train/f56ad584f.jpg
#   inflating: /train/aafdb122a.jpg
#   inflating: /train/6ac3552aa.jpg
#   inflating: /train/a6e953302.jpg
#   inflating: /train/5b74d7499.jpg
#   inflating: /train/3a02a0435.jpg
#   inflating: /train/a575465fa.jpg
#   inflating: /train/798da0bc2.jpg
#   inflating: /train/3d6039ae2.jpg
#   inflating: /train/7c4dc369c.jpg
#   inflating: /train/077059411.jpg
#   inflating: /train/01590e50f.jpg
#   inflating: /train/8ab98da3c.jpg
#   inflating: /train/0df2ad298.jpg
# ...

# %%
train = pd.read_csv(train_ship_segmentations_v2.csv)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full',)).History will not be written to the database.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1b00a367e8d3> in <module>()
# ----> 1 train = pd.read_csv(train_ship_segmentations_v2.csv)
#
# NameError: name 'pd' is not defined

# %%
print(train.head())
print(test.head())
